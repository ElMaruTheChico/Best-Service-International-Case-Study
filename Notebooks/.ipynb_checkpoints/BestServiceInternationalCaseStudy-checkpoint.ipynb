# %% [markdown]
# The purpose of this notebook is to perform analysis for the Best Service International Case Study

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data_folder = "../Data" #defining a relative path to the data file
excel_file_path = os.path.join(data_folder, "Best Service International Sales Data.xlsx") #Construct a full path including the Excel file

excel_file = pd.ExcelFile(excel_file_path)
print('The names of the sheets in the file are as follows:', excel_file.sheet_names)
# Out:
# The names of the sheets in the file are as follows: ['Sales Data', 'PTT Lead Data', 'Staff List']

# %%
dfs = pd.read_excel(excel_file_path, sheet_name=None)
print('The Sales Data table looks as follows')
print(dfs['Sales Data'].head())
print()
print('The Portfolio Tracker Tool table looks as follows')
print(dfs['PTT Lead Data'].head())
print()
print('The Staff List table looks as follows')
print(dfs['Staff List'].head())
# Out:
# The Sales Data table looks as follows
#     Sale Date  Cell Number Sale Consultant Employee Number        Province  \
# 0  2020/01/02    721585874                         D194371  Not Applicable
# 1  2020/01/02    835550504                         D194371  Not Applicable
# 2  2020/01/02    614651899                         D194371  Not Applicable
# 3  2020/01/02    717053334                         D194371  Not Applicable
# 4  2020/01/02    825127720                         D194371  Not Applicable
#
#            Branch           Lead Source conditions          Product Range  \
# 0  Not Applicable  Proactive Engagement         No  Savings & Investments
# 1  Not Applicable  Proactive Engagement        Yes  Savings & Investments
# 2  Not Applicable  Proactive Engagement        Yes  Savings & Investments
# 3  Not Applicable  Proactive Engagement         No  Savings & Investments
# 4  Not Applicable  Proactive Engagement        Yes  Savings & Investments
#
#   Concluded   Valid Sale?
# 0       Yes    Valid Sale
# 1       Yes  Invalid Sale
# 2       Yes    Valid Sale
# 3       Yes    Valid Sale
# 4       Yes  Invalid Sale
#
# The Portfolio Tracker Tool table looks as follows
#    Cell Number Month Sale Consultant Employee Number Customer Location
# 0    721585874   Jan                         D217104           Gauteng
# 1    835550504   Jan                         D198743    Northern Cape
# 2    614651899   Jan                         D215604     Western Cape
# 3    717053334   Jan                         D226001           Limpopo
# 4    825127720   Jan                         D205062       Mpumalanga
#
# The Staff List table looks as follows
#               Name  Employee Number   Team Leader
# 0   Susana Chaffins         D217104     John Smith
# 1        Asley Loch         D198743  Thabo Matangu
# 2      Hedy Kimmell         D215604   Sarah Jacobs
# 3  Martha Frechette         D226001  Jessica Grove
# 4       Luke Torian         D205062   Sarah Jacobs

# %%
print('The Sales Data table has ', dfs['Sales Data'].shape[0], ' rows')
print('The Portfolio Tracker Tool table has ', dfs['PTT Lead Data'].shape[0], ' rows')
print('The Staff List table has ', dfs['Staff List'].shape[0], ' rows')
# Out:
# The Sales Data table has  12018  rows
# The Portfolio Tracker Tool table has  360329  rows
# The Staff List table has  37  rows

# %%
print(dfs['Sales Data'].sample(n=15))
# Out:
#         Sale Date  Cell Number Sale Consultant Employee Number  \
# 5045   2020/02/27    848911975                         D184243
# 2267   2020/01/27    843212114                         D214405
# 2868   2020/01/31    726601742                         D219016
# 11939  2020/12/24    848375114                         D198743
# 11248  2020/11/18    825642309                         D227647
# 752    2020/01/09    724645041                         D194371
# 8868   2020/07/02    724343217                         D216280
# 1335   2020/01/14    711368435                         D217107
# 5362   2020/03/03    818453077                         D215099
# 7729   2020/04/29    832337389                         D215606
# 5017   2020/02/27    835252953                         D215074
# 8553   2020/06/12    821639733                         D216280
# 11965  2020/12/28    834396143                         D215604
# 108    2020/01/03    726555260                         D217055
# 5715   2020/03/06    717391583                         D217092
#
#              Province          Branch           Lead Source conditions  \
# 5045   Not Applicable  Not Applicable  Proactive Engagement        Yes
# 2267   Not Applicable  Not Applicable  Proactive Engagement         No
# 2868          Gauteng        ALBERTON  Proactive Engagement         No
# 11939  Not Applicable  Not Applicable  Proactive Engagement         No
# 11248  Not Applicable  Not Applicable  Proactive Engagement         No
# 752    Not Applicable  Not Applicable  Proactive Engagement        Yes
# 8868   Not Applicable  Not Applicable  Proactive Engagement         No
# 1335   Not Applicable  Not Applicable  Proactive Engagement         No
# 5362   Not Applicable  Not Applicable  Proactive Engagement         No
# 7729   Not Applicable  Not Applicable  Proactive Engagement         No
# 5017   Not Applicable  Not Applicable  Proactive Engagement         No
# 8553   Not Applicable  Not Applicable  Proactive Engagement        Yes
# 11965  Not Applicable  Not Applicable  Proactive Engagement         No
# 108    Not Applicable  Not Applicable  Proactive Engagement         No
# 5715   Not Applicable  Not Applicable  Proactive Engagement         No
#
#                Product Range Concluded   Valid Sale?
# 5045   Savings & Investments       Yes  Invalid Sale
# 2267   Savings & Investments       Yes    Valid Sale
# 2868   Savings & Investments       Yes    Valid Sale
# 11939        Current Account       Yes    Valid Sale
# 11248                   Loan       Yes    Valid Sale
# 752          Current Account       Yes    Valid Sale
# 8868                    Loan       Yes    Valid Sale
# 1335                    Loan       Yes    Valid Sale
# 5362               Insurance       Yes    Valid Sale
# 7729         Current Account       Yes    Valid Sale
# 5017   Savings & Investments       Yes    Valid Sale
# 8553                    Loan       Yes    Valid Sale
# 11965              Insurance       Yes    Valid Sale
# 108          Current Account       Yes    Valid Sale
# 5715             Credit Card       Yes    Valid Sale

# %% [markdown]
# In order to make the data faster to work with, I will use only the fields I think are important in the Sales Data table. This means dropping the Province, Branch, and Concluded fields. The necessary fields will be added to a new data frame called salesData

# %%
selected_col = ['Sale Date', 'Sale Consultant Employee Number', 'Product Range', 'Valid Sale?']
salesData = dfs['Sales Data'][selected_col]
print(salesData.sample(n=15))
# Out:
#         Sale Date Sale Consultant Employee Number          Product Range  \
# 8842   2020/06/30                         D215474              Insurance
# 340    2020/01/06                         D217092        Current Account
# 2180   2020/01/24                         D217107                   Loan
# 7543   2020/04/16                         D215074                   Loan
# 11799  2020/12/14                         D198743                   Loan
# 2020   2020/01/22                         D219016  Savings & Investments
# 3920   2020/02/13                         D122609  Savings & Investments
# 1980   2020/01/22                         D214405  Savings & Investments
# 292    2020/01/06                         D215074  Savings & Investments
# 6820   2020/03/23                         D184243        Current Account
# 2380   2020/01/28                         D122609  Savings & Investments
# 4882   2020/02/26                         D197761              Insurance
# 10510  2020/10/12                         D215606                   Loan
# 590    2020/01/08                         D216360  Savings & Investments
# 7422   2020/04/07                         D215099  Savings & Investments
#
#       Valid Sale?
# 8842   Valid Sale
# 340    Valid Sale
# 2180   Valid Sale
# 7543   Valid Sale
# 11799  Valid Sale
# 2020   Valid Sale
# 3920   Valid Sale
# 1980   Valid Sale
# 292    Valid Sale
# 6820   Valid Sale
# 2380   Valid Sale
# 4882   Valid Sale
# 10510  Valid Sale
# 590    Valid Sale
# 7422   Valid Sale

# %%
from IPython.display import display #this is so that we can use display to view the tables in a more presentable manner

display(salesData.sample(n=20))
# Out:
#         Sale Date Sale Consultant Employee Number          Product Range  \
# 11502  2020/11/30                         D195038                   Loan
# 5123   2020/02/28                         D215604              Insurance
# 1164   2020/01/13                         D215074        Current Account
# 4285   2020/02/18                         D215099  Savings & Investments
# 7133   2020/03/30                         D122609  Savings & Investments
# 5898   2020/03/10                         D217104  Savings & Investments
# 7125   2020/03/30                         D216360  Savings & Investments
# 9824   2020/09/14                         D215473                   Loan
# 193    2020/01/03                         D223172              Insurance
# 6862   2020/03/23                         D227647  Savings & Investments
# 9410   2020/08/20                         D198743                   Loan
# 3222   2020/02/05                         D194371  Savings & Investments
# 7038   2020/03/26                         D195038  Savings & Investments
# 325    2020/01/06                         D184243  Savings & Investments
# 6767   2020/03/20                         D227647              Insurance
# 3005   2020/02/03                         D215604                   Loan
# 3513   2020/02/08                         D184243  Savings & Investments
# 11351  2020/11/24                         D215074                   Loan
# 2717   2020/01/31                         D217104  Savings & Investments
# 8231   2020/05/26                         D216280            Credit Card
#
#         Valid Sale?
# 11502    Valid Sale
# 5123     Valid Sale
# 1164     Valid Sale
# 4285     Valid Sale
# 7133     Valid Sale
# 5898     Valid Sale
# 7125   Invalid Sale
# 9824     Valid Sale
# 193      Valid Sale
# 6862     Valid Sale
# 9410     Valid Sale
# 3222   Invalid Sale
# 7038     Valid Sale
# 325      Valid Sale
# 6767     Valid Sale
# 3005     Valid Sale
# 3513     Valid Sale
# 11351    Valid Sale
# 2717   Invalid Sale
# 8231     Valid Sale

# %%
display(dfs['PTT Lead Data'].sample(n=20))
# Out:
#         Cell Number Month Sale Consultant Employee Number Customer Location
# 218857    839035734   Aug                         D215604       Mpumalanga
# 241781    794882381   Sep                         D195038        Free State
# 283622    826762594   Oct                         D215074        Free State
# 112594    794231005   Apr                         D226001       Mpumalanga
# 328697    827806764   Nov                         D219016    Kwazulu Natal
# 209304    717987626  July                         D215608           Gauteng
# 47492     717409566   Feb                         D215474    Kwazulu Natal
# 227534    797760683   Aug                         D215474        Free State
# 229877    718120465   Aug                         D223172    Kwazulu Natal
# 88336     824342397   Mar                         D215074    Northern Cape
# 219005    823266285   Aug                         D215604    Kwazulu Natal
# 299294    838453878   Oct                         D198743    Kwazulu Natal
# 309751    796951748   Nov                         D197761      Eastern Cape
# 253613    829845760   Sep                         D215473     Western Cape
# 250376    617045017   Sep                         D127811        Free State
# 331801    797787864   Dec                         D218882      Eastern Cape
# 5588      839128315   Jan                         D198743    Kwazulu Natal
# 103329    832205909   Apr                         D216360           Gauteng
# 263670    792701412   Sep                         D212664       North West
# 293683    826300420   Oct                         D217092       Mpumalanga

# %%
selected_col = ['Month', 'Sale Consultant Employee Number']
leadData = dfs['PTT Lead Data'][selected_col]
display(leadData.sample(n=15))
# Out:
#        Month Sale Consultant Employee Number
# 191138  July                         D223172
# 42952    Feb                         D215608
# 229392   Aug                         D184243
# 143384   May                         D215606
# 92708    Apr                         D195038
# 283954   Oct                         D216280
# 88443    Mar                         D217093
# 141964   May                         D215608
# 288686   Oct                         D215097
# 215160   Aug                         D215099
# 135858   May                         D214405
# 26475    Jan                         D122609
# 204047  July                         D184243
# 95072    Apr                         D216060
# 287078   Oct                         D215608

# %%
selected_col = ['Name ','Employee Number','Team Leader ']
staffData = dfs['Staff List'][selected_col]
display(staffData.sample(n=15))
# Out:
#                  Name  Employee Number   Team Leader
# 19      Merle Brotzman         D216060   Sarah Jacobs
# 25      Lorine Decosta         D216360     John Smith
# 3     Martha Frechette         D226001  Jessica Grove
# 1           Asley Loch         D198743  Thabo Matangu
# 34     Herminia Malsam         D127811  Jessica Grove
# 18   Shenna Charleston         D214430  Bonolo Tshube
# 5           Julee Oler         D215099     John Smith
# 22          Yon Coelho         D218882  Bonolo Tshube
# 32     Armand Theobald         D215608     John Smith
# 14      Laurie Cammack         D217092  Bonolo Tshube
# 13  Kallie Wheelwright         D217093     John Smith
# 20         Kit Mcqueen         D122609     John Smith
# 17        Kiara Ridout         D215074   Sarah Jacobs
# 10       Jeffry Wagers         D158378  Jessica Grove
# 28   Marquis Macmaster         D217107   Sarah Jacobs

# %%
groupedPTT = leadData.groupby(['Sale Consultant Employee Number', 'Month'])
countGroups = groupedPTT.size()
countGroupsDF = countGroups.reset_index(name='Counts')

display(countGroupsDF)
# Out:
#     Sale Consultant Employee Number Month  Counts
# 0                           D122609   Apr     850
# 1                           D122609   Aug     763
# 2                           D122609   Dec     789
# 3                           D122609   Feb     847
# 4                           D122609   Jan     789
# ..                              ...   ...     ...
# 441                         D235282   Mar     776
# 442                         D235282   May     798
# 443                         D235282   Nov     836
# 444                         D235282   Oct     740
# 445                         D235282   Sep     895
#
# [446 rows x 3 columns]

# %% [markdown]
# Above the lead data has been grouped by employee number, then by the months, and there is a count for how many leads have been assigned per employee for every month. This data can help answer the following questions:
# 1. We can compare the count for number of leads to the sales attempted and valid sales
# 2. We can confirm that every employee has been allocated a reasonale amount of leads for every month
# 3. This is an edge case, but we can explore if there is any correlation between the number of leads and sales made (valid or overall)

# %%
groupedLeadData = countGroupsDF.dropna() #this is to remove any invalid entries
display(groupedLeadData)
# Out:
#     Sale Consultant Employee Number Month  Counts
# 0                           D122609   Apr     850
# 1                           D122609   Aug     763
# 2                           D122609   Dec     789
# 3                           D122609   Feb     847
# 4                           D122609   Jan     789
# ..                              ...   ...     ...
# 441                         D235282   Mar     776
# 442                         D235282   May     798
# 443                         D235282   Nov     836
# 444                         D235282   Oct     740
# 445                         D235282   Sep     895
#
# [446 rows x 3 columns]

# %%
employees = groupedLeadData['Sale Consultant Employee Number'].unique()
print(len(employees))
# Out:
# 37

# %%
37 * 12
# Out:
# 444

# %%
plt.scatter(groupedLeadData.index, groupedLeadData['Counts'])
plt.xlabel('Index')
plt.ylabel('Number of leads')
plt.title('Scatter plot showing the number of leads each employee received per month')
plt.show()

# %%
display(groupedLeadData[groupedLeadData['Counts'] < 200])
# Out:
#     Sale Consultant Employee Number  Month  Counts
# 150                         D214405  July        1
# 271                         D215608  July        1

# %%
display(groupedLeadData[groupedLeadData['Sale Consultant Employee Number'] == 'D214405'])
# Out:
#     Sale Consultant Employee Number  Month  Counts
# 144                         D214405    Apr     850
# 145                         D214405    Aug     763
# 146                         D214405    Dec     788
# 147                         D214405    Feb     846
# 148                         D214405    Jan     789
# 149                         D214405   July     869
# 150                         D214405  July        1
# 151                         D214405    Jun     788
# 152                         D214405    Mar     776
# 153                         D214405    May     797
# 154                         D214405    Nov     837
# 155                         D214405    Oct     740
# 156                         D214405    Sep     894

# %%
display(groupedLeadData[groupedLeadData['Sale Consultant Employee Number'] == 'D215608'])
# Out:
#     Sale Consultant Employee Number  Month  Counts
# 265                         D215608    Apr     850
# 266                         D215608    Aug     763
# 267                         D215608    Dec     788
# 268                         D215608    Feb     846
# 269                         D215608    Jan     789
# 270                         D215608   July     869
# 271                         D215608  July        1
# 272                         D215608    Jun     788
# 273                         D215608    Mar     776
# 274                         D215608    May     797
# 275                         D215608    Nov     837
# 276                         D215608    Oct     740
# 277                         D215608    Sep     894

# %% [markdown]
# From the above it is clear that each employee received upward of 700 leads monthly, and the only months that show otherwise are a mistake that happens for the month of July, twice.

# %%
groupedStaffData = staffData.groupby('Team Leader ')
countGroups = groupedStaffData.size()
employeesPerLead = countGroups.reset_index(name='Employees per team')

display(employeesPerLead)
# Out:
#     Team Leader   Employees per team
# 0  Bonolo Tshube                   8
# 1  Jessica Grove                   4
# 2     John Smith                  13
# 3   Sarah Jacobs                   9
# 4  Thabo Matangu                   3

# %% [markdown]
# We can see from the above that the team sizes are not equal, if we are to compare the performance of each team we need to find an average amount as the data may possibly be skewed by team size

# %% [markdown]
# Useful data structures:
# 1. employeesPerLead
# 2. staffData
# 3. salesData

# %%
display(salesData.sample(n=20))
# Out:
#         Sale Date Sale Consultant Employee Number          Product Range  \
# 3183   2020/02/04                         D176968  Savings & Investments
# 1490   2020/01/15                         D215474  Savings & Investments
# 2169   2020/01/24                         D214405  Savings & Investments
# 2833   2020/01/31                         D226001            Credit Card
# 1139   2020/01/13                         D216360  Savings & Investments
# 2695   2020/01/30                         D205062  Savings & Investments
# 186    2020/01/03                         D217092  Savings & Investments
# 4933   2020/02/26                         D198743            Credit Card
# 11709  2020/12/08                         D215604              Insurance
# 4395   2020/02/19                         D235282                   Loan
# 4706   2020/02/24                         D215099  Savings & Investments
# 10743  2020/10/26                         D122609                   Loan
# 2853   2020/01/31                         D217092  Savings & Investments
# 5597   2020/03/05                         D215604                   Loan
# 10311  2020/10/02                         D122609                   Loan
# 7789   2020/05/04                         D217107                   Loan
# 6387   2020/03/16                         D216280  Savings & Investments
# 9932   2020/09/17                         D215606  Savings & Investments
# 9486   2020/08/24                         D198743  Savings & Investments
# 8785   2020/06/26                         D215606                   Loan
#
#         Valid Sale?
# 3183     Valid Sale
# 1490   Invalid Sale
# 2169     Valid Sale
# 2833     Valid Sale
# 1139     Valid Sale
# 2695     Valid Sale
# 186      Valid Sale
# 4933   Invalid Sale
# 11709    Valid Sale
# 4395     Valid Sale
# 4706     Valid Sale
# 10743    Valid Sale
# 2853     Valid Sale
# 5597     Valid Sale
# 10311    Valid Sale
# 7789     Valid Sale
# 6387     Valid Sale
# 9932     Valid Sale
# 9486     Valid Sale
# 8785   Invalid Sale

# %% [markdown]
# Trends that we will be exploring for the sales data:
# 1. Counting the sales per employee per month (compare to baseline assuming 3 sales per day)(visual)
# 2. Sales validity per product range (visual to compare)
# 3. Exploring sales per day and the correlation between that and the team lead

# %%
#salesData['Sale Date'] = pd.to_datetime(salesData['Sale Date']) this threw an error
salesData.loc[:, 'Sale Date'] = pd.to_datetime(salesData['Sale Date']) #this is a second attempt at converting the date to a datetime

# %% [markdown]
# The average number of workdays in a month, assuming the workdays are Monday to Friday, can be calculated by considering the typical number of days in a month and excluding weekends.
#
# Here's a quick breakdown:
#
# A year has 365 days (or 366 in a leap year).
#
# There are 52 weeks in a year.
#
# Each week has 5 workdays (Monday to Friday) and 2 weekend days (Saturday and Sunday).
#
# 52 weeks × 5 workdays = 260 workdays in a year.
#
# Since there are 12 months in a year, the average number of workdays per month would be: $$\text{Average workdays per month} = \frac{260 \text{ workdays}}{12 \text{ months}} \approx 21.67 \text{ workdays per month}$$
#
# So, on average, there are about 21 to 22 workdays in a month. Of course, this can vary slightly depending on the specific month and any public holidays that may fall on weekdays. We will be working with the assumption that there are 21 workdays in a month

# %%
workDaysPerMonth = 21

# %%
salesData.loc[:, 'Month'] = salesData['Sale Date'].dt.month

# %%
display(salesData.sample(n=20))
# Out:
#        Sale Date Sale Consultant Employee Number          Product Range  \
# 9812  2020-09-11                         D198743        Current Account
# 9202  2020-08-06                         D217093            Credit Card
# 10135 2020-09-25                         D227647                   Loan
# 9165  2020-07-29                         D205062                   Loan
# 7927  2020-05-11                         D214376                   Loan
# 6834  2020-03-23                         D214376              Insurance
# 6734  2020-03-20                         D216360  Savings & Investments
# 10253 2020-09-30                         D227647              Insurance
# 3086  2020-02-04                         D217055  Savings & Investments
# 1150  2020-01-13                         D215473  Savings & Investments
# 9362  2020-08-18                         D195038        Current Account
# 7651  2020-04-23                         D197761                   Loan
# 6181  2020-03-12                         D198743            Credit Card
# 2352  2020-01-28                         D216360            Credit Card
# 1001  2020-01-10                         D217092  Savings & Investments
# 2215  2020-01-25                         D195038        Current Account
# 7369  2020-04-03                         D215099                   Loan
# 11524 2020-12-01                         D184243                   Loan
# 9240  2020-08-11                         D216280                   Loan
# 10322 2020-10-02                         D215606                   Loan
#
#         Valid Sale?  Month
# 9812     Valid Sale      9
# 9202     Valid Sale      8
# 10135  Invalid Sale      9
# 9165     Valid Sale      7
# 7927     Valid Sale      5
# 6834     Valid Sale      3
# 6734     Valid Sale      3
# 10253    Valid Sale      9
# 3086     Valid Sale      2
# 1150     Valid Sale      1
# 9362     Valid Sale      8
# 7651     Valid Sale      4
# 6181     Valid Sale      3
# 2352     Valid Sale      1
# 1001   Invalid Sale      1
# 2215     Valid Sale      1
# 7369     Valid Sale      4
# 11524  Invalid Sale     12
# 9240     Valid Sale      8
# 10322    Valid Sale     10

# %%
groupedSalesData = salesData.groupby(['Sale Consultant Employee Number', 'Month'])
countEmployeeMonth = groupedSalesData.size()
employeeSalesPMonth = countEmployeeMonth.reset_index(name='Sales per month')

display(employeeSalesPMonth)
# Out:
#     Sale Consultant Employee Number  Month  Sales per month
# 0                           D122609      1              101
# 1                           D122609      2              124
# 2                           D122609      3              153
# 3                           D122609      4                4
# 4                           D122609      5               39
# ..                              ...    ...              ...
# 272                         D235282      3               62
# 273                         D235282      4                6
# 274                         D235282      5                4
# 275                         D235282      7                2
# 276                         D235282      9                2
#
# [277 rows x 3 columns]

# %% [markdown]
# The table above shows us the sales per month for each employee every month. I am now going to convert this to the call per day rate using the work days per month constant referenced earlier. Employees meeting their target should have their sales rate at 3 and above

# %%
employeeSalesPMonth.loc[:, 'Sales Rate'] = employeeSalesPMonth['Sales per month']/workDaysPerMonth

# %%
display(employeeSalesPMonth)
# Out:
#     Sale Consultant Employee Number  Month  Sales per month  Sales Rate
# 0                           D122609      1              101    4.809524
# 1                           D122609      2              124    5.904762
# 2                           D122609      3              153    7.285714
# 3                           D122609      4                4    0.190476
# 4                           D122609      5               39    1.857143
# ..                              ...    ...              ...         ...
# 272                         D235282      3               62    2.952381
# 273                         D235282      4                6    0.285714
# 274                         D235282      5                4    0.190476
# 275                         D235282      7                2    0.095238
# 276                         D235282      9                2    0.095238
#
# [277 rows x 4 columns]

# %%
plt.scatter(employeeSalesPMonth.index, employeeSalesPMonth['Sales Rate'])
plt.xlabel('Index')
plt.ylabel('Sales rate per month')
plt.title('Scatter plot showing the sales rate per month')
plt.axhline(y=3, color='red', linestyle='--', linewidth=2, label='Sales rate target = 3')
plt.show()

# %% [markdown]
# From the scatter plot above we can see that most of the months the employees sales rate is well below the target of 3 sales per day. We are going to do a further breakdown to see if there are any correlations with:
# 1. The month
# 2. Specific sales consultants
# 3. Specific sales consultants team leads
#
# An update to the useful datastructures:
# 1. employeesPerLead
# 2. staffData
# 3. salesData
# 4. employeeSalesPMonth
# 5. employeesPerLead

# %%
meanMonthlySalesRate = employeeSalesPMonth.groupby('Month')['Sales Rate'].mean()
meanMonthlySalesRate = meanMonthlySalesRate.reset_index()
display(meanMonthlySalesRate)
# Out:
#     Month  Sales Rate
# 0       1    4.297619
# 1       2    3.290043
# 2       3    4.072381
# 3       4    0.995671
# 4       5    1.055556
# 5       6    1.021978
# 6       7    1.197802
# 7       8    0.934240
# 8       9    1.458874
# 9      10    1.555556
# 10     11    1.621554
# 11     12    1.112554

# %%
plt.bar(meanMonthlySalesRate['Month'],meanMonthlySalesRate['Sales Rate'])
plt.xlabel('Month') 
plt.ylabel('Mean Sales Rate') 
plt.title('Mean Sales Rate per Month') 
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# It is clear from the bar graph above that on average there is a steep drop off in sales attempted after the pandemic hit in April. We will separate the months before and after the pandemic for sanitary purposes for any analysis going forward. This is because the data being recorded after the pandemic is fundamentally different. The focus of the problem and solution is also focused post-pandemic.

# %% [markdown]
# Next up:
# separate the data pre and post pandemic
# merge the employee team lead data into the sales table so we can start spotting trends
